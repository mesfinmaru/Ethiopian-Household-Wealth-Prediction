# %% [markdown]
# # Ethiopian Household Welfare Prediction (ESS Multi-wave)
# This notebook demonstrates EDA, modeling, and regional analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from src.pipeline import run_pipeline

# %% [markdown]
# ## Configure wave paths and run training pipeline

# %%
wave_map = {2011: 'data/2011', 2013: 'data/2013', 2015: 'data/2015', 2018: 'data/2018', 2021: 'data/2021'}
# metrics = run_pipeline(wave_map)
# print(metrics)

# %% [markdown]
# ## EDA and Visualization

# %%
pred = pd.read_csv('outputs/predictions.csv')
pred.head()

# %%
if 'consumption_per_capita' in pred.columns:
    sns.histplot(pred['consumption_per_capita'], kde=True)
    plt.title('Consumption Per Capita Distribution')
    plt.show()

# %% [markdown]
# ## Regional Analysis

# %%
reg = pd.read_csv('outputs/avg_consumption_by_region.csv')
reg.sort_values('avg_pred_consumption', ascending=False).head(10)

# %%
pov = pd.read_csv('outputs/poverty_rate_region_zone.csv')
pov.head()
