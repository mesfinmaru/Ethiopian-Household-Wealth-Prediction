# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..') 
from src.cleaning import DataCleaner
from src.preprocessing import Preprocessor

# %%
cleaner = DataCleaner()
prep = Preprocessor()

waves = cleaner.load_raw_data('../data/raw/')
w5 = waves['cons_agg_2021-22_w5']

# %%
w5 = cleaner.standardize_regions(w5)
w5 = prep.rename_essential_columns(w5)
w5_clean = prep.handle_outliers(w5)

w5_clean.to_csv('../data/processed/w5_cleaned.csv', index=False)
print("Data Refined for 2021.")
# Out:
# Data Refined for 2021.
